# %%
### https://adventofcode.com/2023/day/21


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return [line.strip() for line in f_in.readlines()]
    

def get_solution_1(data):
    pass
        
    
def get_solution_2(data):
    pass




file = "data/day_21.txt"

data = read_file(file)
solution_1 = get_solution_1(data)
solution_2 = get_solution_2(data)

print("Day 21 - Solution 1:", solution_1)
print("Day 21 - Solution 2:", solution_2)

# %%
### https://adventofcode.com/2023/day/22


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return [line.strip() for line in f_in.readlines()]
    

def get_solution_1(data):
    pass
        
    
def get_solution_2(data):
    pass




file = "data/day_22.txt"

data = read_file(file)
solution_1 = get_solution_1(data)
solution_2 = get_solution_2(data)

print("Day 22 - Solution 1:", solution_1)
print("Day 22 - Solution 2:", solution_2)

# %%
### https://adventofcode.com/2023/day/23


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return [line.strip() for line in f_in.readlines()]
    

def get_solution_1(data):
    pass
        
    
def get_solution_2(data):
    pass




file = "data/day_23.txt"

data = read_file(file)
solution_1 = get_solution_1(data)
solution_2 = get_solution_2(data)

print("Day 23 - Solution 1:", solution_1)
print("Day 23 - Solution 2:", solution_2)

# %%
### https://adventofcode.com/2023/day/24


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return [line.strip() for line in f_in.readlines()]
    

def get_solution_1(data):
    pass
        
    
def get_solution_2(data):
    pass




file = "data/day_24.txt"

data = read_file(file)
solution_1 = get_solution_1(data)
solution_2 = get_solution_2(data)

print("Day 24 - Solution 1:", solution_1)
print("Day 24 - Solution 2:", solution_2)

# %%
### https://adventofcode.com/2023/day/25


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return [line.strip() for line in f_in.readlines()]
    

def get_solution_1(data):
    pass
        
    
def get_solution_2(data):
    pass




file = "data/day_25.txt"

data = read_file(file)
solution_1 = get_solution_1(data)
solution_2 = get_solution_2(data)

print("Day 25 - Solution 1:", solution_1)
print("Day 25 - Solution 2:", solution_2)
